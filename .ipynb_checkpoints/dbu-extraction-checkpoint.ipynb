# %%
import os
import pandas as pd

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# C:\SFS

# %%
head = pd.read_csv(os.path.join(cwd, 'data', 'results', 'db-unification','head_DBU-COMPLETE.csv'), index_col = 'DATA')
meta = pd.read_csv(os.path.join(cwd, 'data', 'results', 'db-unification','meta_DBU-COMPLETE.csv'), index_col = 'CODICE')
head.index = pd.to_datetime(head.index)

# %%
head.tail()
# Out:
#             PO012002NU0008  PO012026NU3021  PO0120500RZ001  PO012070NU1007  \
# DATA
# 2022-03-01             NaN             NaN             NaN             NaN
# 2022-04-01             NaN             NaN             NaN             NaN
# 2022-05-01             NaN             NaN             NaN             NaN
# 2022-06-01             NaN             NaN             NaN             NaN
# 2022-07-01             NaN             NaN             NaN             NaN
#
#             PO0120750R2020  PO0120790RZ001  PO012090NU2009  PO0121180U0005  \
# DATA
# 2022-03-01             NaN             NaN             NaN             NaN
# 2022-04-01             NaN             NaN             NaN             NaN
# 2022-05-01             NaN             NaN             NaN             NaN
# 2022-06-01             NaN             NaN             NaN             NaN
# 2022-07-01             NaN             NaN             NaN             NaN
#
#             PO012123NUP001  PO0121300RZ001  ...  FOG24  FOG27  FOG34  FOG41  \
# DATA                                        ...
# 2022-03-01             NaN             NaN  ...    NaN    NaN    NaN    NaN
# 2022-04-01             NaN             NaN  ...    NaN    NaN    NaN    NaN
# 2022-05-01             NaN             NaN  ...    NaN    NaN    NaN    NaN
# 2022-06-01             NaN             NaN  ...    NaN    NaN    NaN    NaN
# 2022-07-01             NaN             NaN  ...    NaN    NaN    NaN    NaN
#
#             FOG56  FOG72  PO015209NR0264  CM.PS.002  PO015209NR0336  \
# DATA
# 2022-03-01    NaN    NaN          121.71     127.02          124.97
# 2022-04-01    NaN    NaN             NaN     126.57          124.83
# 2022-05-01    NaN    NaN             NaN     126.55          124.35
# 2022-06-01    NaN    NaN             NaN     126.06          124.15
# 2022-07-01    NaN    NaN             NaN     125.88          123.83
#
#             PO015209NRA683
# DATA
# 2022-03-01          126.14
# 2022-04-01          125.89
# 2022-05-01          125.61
# 2022-06-01          125.34
# 2022-07-01          125.08
#
# [5 rows x 64 columns]

# %%
start = '2015-01-01'
end = '2015-01-31'

# %%
sel = head.loc[head.index.isin(pd.date_range(start, end)),:].transpose()
join = sel.merge(meta.loc[sel.index, ['lat', 'lon']], left_index = True, right_index = True)
join.columns = ['value', 'lat', 'lon']

# %%
join.to_csv(os.path.join(cwd, '2015-01-piezo.csv'))
